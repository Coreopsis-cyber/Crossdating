# %%
# %matplotlib inline

import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np 
#Importing packages needed for the model
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import precision_recall_fscore_support
from collections import Counter
from sklearn.utils import resample
from sklearn.metrics import make_scorer, recall_score, accuracy_score, precision_score

# %%
try:
    df1 = pd.read_csv('./Training_Data/training_tree_1.csv', index_col=0)
    df2 = pd.read_csv('./Training_Data/training_tree_2.csv', index_col=0)
    df3 = pd.read_csv('./Training_Data/training_tree_3.csv', index_col=0)
    df4 = pd.read_csv('./Training_Data/training_tree_4.csv', index_col=0)
    df5 = pd.read_csv('./Training_Data/training_tree_5.csv', index_col=0)
    df6 = pd.read_csv('./Training_Data/training_tree_6.csv', index_col=0)
    df7 = pd.read_csv('./Training_Data/training_tree_7.csv', index_col=0)
    df8 = pd.read_csv('./Training_Data/training_tree_8.csv', index_col=0)
    df9 = pd.read_csv('./Training_Data/training_tree_9.csv', index_col=0)
    df10 = pd.read_csv('./Training_Data/training_tree_10.csv', index_col=0)
    df11 = pd.read_csv('./Training_Data/training_tree_11.csv', index_col=0)
    df12 = pd.read_csv('./Training_Data/training_tree_12.csv', index_col=0)
    df13 = pd.read_csv('./Training_Data/training_tree_13.csv', index_col=0)
    df14 = pd.read_csv('./Training_Data/training_tree_14.csv', index_col=0)
    df15 = pd.read_csv('./Training_Data/training_tree_15.csv', index_col=0)
except FileNotFoundError:
    print("File not found. Please check the file is in the current working directory and has been spelt correctly")
except pd.errors.EmptyDataError:
    print("No data.")
except pd.errors.ParserError:
    print("Parse error.")
except Exception:
    print("An error occured.")

# %%
df15.head()
# Out:
#       master_chronology  SLC01A
# year
# 1630           2.235870     NaN
# 1631           1.132329     NaN
# 1632          -0.841564     NaN
# 1633          -0.130124     NaN
# 1634           1.247763     NaN

# %% [markdown]
# # Functions to make the binary classifiers for training

# %%
def making_more_testing_data(df):
    samples = []
    samples1 = []
    answer = []
    segments = {}
    i= 0
    for col in df.columns:
        col_list = df[col].tolist()
        cleanedList = [x for x in col_list if x == x]
        samples.append(cleanedList)
        
    segments = {}
    size = 100
    step = 50
    length = len(samples)
    segments[0] = ([samples[0][i : i + size] for i in range(0, len(samples[0]), step)])

  

    short0 = []

    
    for j in range(len(segments[0])):
        if len(segments[0][j]) != 100:
            
            short0.append(segments[0][j])
               
        else:
            continue
        
        
    size = 10
    step = 1
    length = len(samples)
    
    segments[1] = ([samples[1][i : i + size] for i in range(0, len(samples[1]), step)])

   

    short1 = []

    for j in range(len(segments[1])):
        if len(segments[1][j]) != 10:
         
            short1.append(segments[1][j])
               
        else:
            continue
        


    segments0 = [x for x in segments[0] if x not in short0]
    segments1 = [x for x in segments[1] if x not in short1]
    

    segments[0] = segments0
    segments[1] = segments1

    segments[0][-1]
    assert len(segments[0][-1]) == 100
    assert len(segments[1][-1]) == 10
    segments0 = segments[0]
    segments1 = segments[1]
    pairs =  [(x + y) for x in segments0 for y in segments1]
        
    while i < (df.shape[0]-100):
        new = df.iloc[i:i+100]
        new.shape
        for col in new.columns:
            col_list = new[col].tolist()
            cleanedList = [x for x in col_list if x == x]
            samples1.append(cleanedList)   
        i+=50
        
    assert len(samples1[-2]) == 100
    

    i = 1
    while i < len(samples1):

        if len(samples1[i]) < 10:
            for j in range(len(segments[1])):
                answer.append(0)
        elif len(samples1[i])==10:
            if find_element_in_list(samples1[i], segments[1]) != None:
                index = find_element_in_list(samples1[i], segments[1])
                for j in range(len(segment[1]- index-1)):
                    answer.append(0)
                answer.append(1)
                for j in range(len(segment[1]- index)):
                    answer.append(0)
            elif find_element_in_list(samples[i], segments[1]) == None:
                for j in range(len(segment[1])):
                    answer.append(0)
        elif len(samples1[i]) > 10:
            size = 10
            step = 1
            length = len(samples1[i])
            seg = {}
            fnal = []
            seg[0] = ([samples1[i][j : j + size] for j in range(0, len(samples1[i]), step)])


            short2 = []

            for j in range(len(seg[0])):
                if len(seg[0][j]) != 10:
                   
                    short2.append(seg[0][j])
                else:
                    continue
        
            
            final = [x for x in seg[0] if x not in short2]
            
            for j in range(len(segments[1])):
                if find_element_in_list(segments[1][j], final) != None:
                   
                    answer.append(1)
                else: 
                    
                    answer.append(0)
        i+=2
    
    return pairs, answer

# %%
def correct_pairs(df):
    pair = []
    col_list = []
    correct = []
    samples = []
    no_repeat_correct = []
    i= 0
    for col in df.columns:
        col_list = df[col].tolist()
        cleanedList = [x for x in col_list if x == x]
        samples.append(cleanedList)
    for i in range(np.where(df.iloc[:,1 ] == samples[1][0])[0][0],(np.where(df.iloc[:,1 ] == samples[1][-1])[0][0]-8)):
        new = df.iloc[i:i+10]
        
        for col in new.columns:
            col_list = new[col].tolist()
            
            pair.append(col_list)
        correct.append(pair[0] + pair[1])
        pair = []
    no_repeat_correct = [i for n, i in enumerate(correct) if i not in correct[:n]]
   
    return no_repeat_correct

# %%
def find_element_in_list(element, list_element):
    try:
        index_element = list_element.index(element)
        return index_element
    except ValueError:
        return None

# %%
def create_pairs(dataframe, section):
    samples = []
    segments = {}
    segment = {}
    size = 10
    step = 1
    i= 0
    for df in dataframe:
        col_list = df.iloc[:, 1].tolist()
        cleanedList = [x for x in col_list if x == x]
        samples.append(cleanedList)
        #print(df)
    
    
    for j in range(len(section)):
        key = int(j)
        segments[key] = ([section[j][i : i + size] for i in range(0, len(section[j]), step)])
    
    for k in range(len(samples)):
        key = int(len(section) + k)
        segments[key] = ([samples[k][i : i + size] for i in range(0, len(samples[k]), step)])
       
    #print(segments[0])
    #print(segments[1])

        
    short = []
    
    for i in range(len(segments)):
        for j in range(len(segments[i])):
            if len(segments[i][j]) != 10:
                short.append(segments[i][j])
            else:
                continue
                
    print(len(segments))
    #print(short)
    master = []
    for i in range(len(section)):
        #print(segments[i])
        master.append([x for x in segments[i] if x not in short])
        #print(master[i])
    #print(master)
    sample = []
    for i in range(len(samples)):
        sample.append([x for x in segments[i+len(section)] if x not in short])

    #print(segments0)
    
    segment[0] = [item for sublist in master for item in sublist]
    segment[1] = [item for sublist in sample for item in sublist]
    print(len(segment[0]))
    print(len(segment[1]))
    segments[0][-1]
    segments0 = segment[0]
    segments1 = segment[1]
    pairs =  [(x + y) for x in segments0 for y in segments1]
    assert len(pairs[-1]) == 20
    #print(pairs[0])
    print(len(pairs))
    
    return pairs

# %%
print(len(train_input_no_dup))
train_input_pairs = create_pairs([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], train_input_no_dup)
# Out:
# 5
# 19
# 455
# 2470
# 1123850

# %%
train_input_pairs = create_pairs([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], train_input_no_dup)
# Out:
#       master_chronology    SLC08A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.418635
# 1992           1.510471  1.606258
# 1993           1.399487  2.468107
# 1994          -0.236549  0.752298
# 1995           1.370315  0.483366
#
# [366 rows x 2 columns]
#       master_chronology    SLC07B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.771311
# 1992           1.510471  2.872836
# 1993           1.399487  1.310599
# 1994          -0.236549 -0.825097
# 1995           1.370315  0.679461
#
# [366 rows x 2 columns]
#       master_chronology    SLC07A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.569248
# 1992           1.510471  2.246548
# 1993           1.399487  1.990881
# 1994          -0.236549  0.088342
# 1995           1.370315  1.623497
#
# [366 rows x 2 columns]
#       master_chronology    SLC06B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.996815
# 1992           1.510471  1.409192
# 1993           1.399487  1.799999
# 1994          -0.236549 -0.452017
# 1995           1.370315  1.823759
#
# [366 rows x 2 columns]
#       master_chronology    SLC05B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.895386
# 1992           1.510471  1.690698
# 1993           1.399487  1.615531
# 1994          -0.236549 -0.746369
# 1995           1.370315  1.742115
#
# [366 rows x 2 columns]
#       master_chronology    SLC06A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.546358
# 1992           1.510471  1.213632
# 1993           1.399487  1.927465
# 1994          -0.236549 -0.046801
# 1995           1.370315  1.612224
#
# [366 rows x 2 columns]
#       master_chronology    SLC05A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.696656
# 1992           1.510471  1.319566
# 1993           1.399487  1.743868
# 1994          -0.236549 -0.426104
# 1995           1.370315  1.465922
#
# [366 rows x 2 columns]
#       master_chronology    SLC04B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.324909
# 1992           1.510471  2.072903
# 1993           1.399487  2.154732
# 1994          -0.236549 -0.771648
# 1995           1.370315  1.024795
#
# [366 rows x 2 columns]
#       master_chronology    SLC04A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.891876
# 1992           1.510471  1.240107
# 1993           1.399487  1.541581
# 1994          -0.236549 -0.397029
# 1995           1.370315  2.212659
#
# [366 rows x 2 columns]
#       master_chronology  SLC03B
# year
# 1630           2.235870     NaN
# 1631           1.132329     NaN
# 1632          -0.841564     NaN
# 1633          -0.130124     NaN
# 1634           1.247763     NaN
# ...                 ...     ...
# 1991           1.452270     NaN
# 1992           1.510471     NaN
# 1993           1.399487     NaN
# 1994          -0.236549     NaN
# 1995           1.370315     NaN
#
# [366 rows x 2 columns]
#       master_chronology    SLC03A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  2.029666
# 1992           1.510471  0.744454
# 1993           1.399487  0.692761
# 1994          -0.236549 -0.213533
# 1995           1.370315  1.649689
#
# [366 rows x 2 columns]
#       master_chronology    SLC02B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.309737
# 1992           1.510471  1.629997
# 1993           1.399487  1.466743
# 1994          -0.236549 -0.546406
# 1995           1.370315  1.740003
#
# [366 rows x 2 columns]
#       master_chronology    SLC02A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  2.259642
# 1992           1.510471  1.884882
# 1993           1.399487  0.507323
# 1994          -0.236549 -0.632597
# 1995           1.370315  1.747377
#
# [366 rows x 2 columns]
#       master_chronology    SLC01B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.603772
# 1992           1.510471  1.168856
# 1993           1.399487  1.243103
# 1994          -0.236549 -0.098164
# 1995           1.370315  1.344243
#
# [366 rows x 2 columns]
# [[2.378518557, 1.741895741, -0.266913001, 1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643], [1.741895741, -0.266913001, 1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298], [-0.266913001, 1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039], [1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666], [-0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916], [0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848], [0.085445783, 0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943], [0.704041413, 1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896], [1.665141301, 2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747], [2.767813643, 2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401], [2.170900298, 0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334], [0.243487039, 0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169], [0.004346666, -0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426], [-0.215046916, 1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814], [1.668628848, 2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773], [2.489597943, 2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415], [2.169819896, 1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678], [1.304669747, 1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006], [1.567632401, 0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749], [0.744599334, 0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595], [0.565442169, -0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094], [-0.587648426, 1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155], [1.246356814, -0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251], [-0.272311773, 0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991], [0.57766415, -0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454], [-0.581722678, 0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454, 1.309996337], [0.764354006, 1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454, 1.309996337, 1.881858432], [1.238099749, 0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454, 1.309996337, 1.881858432, -0.013454182], [0.6980595, 1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454, 1.309996337, 1.881858432, -0.013454182, -0.44553313], [1.287893094, 2.114935155, 0.715560251, 1.191546991, 2.371838454, 1.309996337, 1.881858432, -0.013454182, -0.44553313, 1.974569414], [2.114935155, 0.71 ...
# 218
# [2.259505324, 1.61886373, 1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 2.378518557, 1.741895741, -0.266913001, 1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643]
# 19838

# %%
def create_overlap_binary_class(pairs, correct_pairs):
    
    binary = []
    first_pairs = []
    for j in range(len(correct_pairs)): 
        first_pairs.append(correct_pairs[j][:5])
    correct_pairs = [item for sublist in correct_pairs for item in sublist]
    i=0
    while i < len(pairs):
        
        if pairs[i] in correct_pairs and pairs[i] in first_pairs:
            for t in range(len(first_pairs)):
                if pairs[i] in first_pairs[t]: 
                    for j in range(0,first_pairs[t].index(pairs[i])): 
                        binary.pop()
                    for h in range(0,first_pairs[t].index(pairs[i])):
                        binary.append(1)
                    for f in range(6):
                        binary.append(1)
                    i+=6
        elif pairs[i] in correct_pairs:
            for z in range(0,5):
                binary.pop()
            for f in range(0,11):
                binary.append(1)
            i+=6  
        else: 
            binary.append(0)
            i+=1
    return binary

# %%
def create_overlap_binary_test_class(pairs, correct_pairs):
    binary = []
    found_pairs = []
    i=0
    while i < len(pairs):
        if pairs[i] in correct_pairs:
            if correct_pairs.index(pairs[i]) < 5: 
                for j in range(0,correct_pairs.index(pairs[i])): 
                    binary.pop()
                for h in range(0,correct_pairs.index(pairs[i])):
                    binary.append(1) 
                for f in range(6):
                    binary.append(1)
                    
                i+=6
            else:
                for z in range(0,5):
                    binary.pop() 
                if i < len(pairs)-6:
                    for f in range(0,11):
                        binary.append(1)
                else:
                    for f in range(5+len(pairs)-i):
                        binary.append(1)   
                i+=6  
        else: 
            binary.append(0)
            
            i+=1
    return binary

# %%
def create_binary_class(pairs, correct_pairs):
    binary = []
    for i in range(len(pairs)):
        if pairs[i] in correct_pairs:
            binary.append(1)
        else: 
            binary.append(0)
    return binary

# %%
def create_binary_training_class(pairs, correct_pairs):
    binary = []
    correct_pairs = [item for sublist in correct_pairs for item in sublist]
    for i in range(len(pairs)):
        if pairs[i] in correct_pairs:
            binary.append(1)
        else: 
            binary.append(0)
    return binary

# %% [markdown]
# # Making the testing data

# %%
first_match1, first_output1 = making_more_testing_data(df1)
first_match2, first_output2 = making_more_testing_data(df2)
first_match3, first_output3 = making_more_testing_data(df3)
first_match4, first_output4 = making_more_testing_data(df4)
first_match5, first_output5 = making_more_testing_data(df5)
first_match6, first_output6 = making_more_testing_data(df6)
first_match7, first_output7 = making_more_testing_data(df7)
first_match8, first_output8= making_more_testing_data(df8)
first_match9, first_output9 = making_more_testing_data(df9)
first_match10, first_output10 = making_more_testing_data(df10)
first_match11, first_output11 = making_more_testing_data(df11)
first_match12, first_output12 = making_more_testing_data(df12)
first_match13, first_output13 = making_more_testing_data(df13)
first_match14, first_output14 = making_more_testing_data(df14)
first_match15, first_output15 = making_more_testing_data(df15)

# %%
correct_pair1 = correct_pairs(df1)
correct_pair2 = correct_pairs(df2) 
correct_pair3 = correct_pairs(df3) 
correct_pair4 = correct_pairs(df4) 
correct_pair5 = correct_pairs(df5) 
correct_pair6 = correct_pairs(df6) 
correct_pair7 = correct_pairs(df7) 
correct_pair8 = correct_pairs(df8) 
correct_pair9 = correct_pairs(df9) 
correct_pair10 = correct_pairs(df10) 
correct_pair11 = correct_pairs(df11) 
correct_pair12 = correct_pairs(df12) 
correct_pair13 = correct_pairs(df13) 
correct_pair14 = correct_pairs(df14) 
correct_pair15 = correct_pairs(df15)
correct_pair_training = [correct_pair1, correct_pair2, correct_pair3, correct_pair4, correct_pair5, correct_pair6, correct_pair7, correct_pair8, correct_pair9, correct_pair10, correct_pair11, correct_pair12, correct_pair13, correct_pair14]
print(len(correct_pair_training))
total = 0
for i in range(len(correct_pair_training)):
    total += len(correct_pair_training[i])
print(total)
# Out:
# 14
# 2470

# %%
total_first_matches = first_match1 + first_match2 + first_match3 + first_match4 + first_match5 + first_match6 + first_match7 + first_match8 + first_match9 + first_match10 + first_match11 + first_match12 + first_match13 + first_match14
total_first_ouputs = first_output1 + first_output2 + first_output3 + first_output4 + first_output5 + first_output6 + first_output7 + first_output8 + first_output9 + first_output10 + first_output11 + first_output12 + first_output13 + first_output14 
x = total_first_matches
y = total_first_ouputs
strat = pd.Series(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4, stratify= strat )
print('Training Data: ')
print(len(x_train))
print('----------------------------------------------')
print('Testing Data: ')
print(len(x_test))
# Out:
# Training Data:
# 8892
# ----------------------------------------------
# Testing Data:
# 5928

# %%
mlp = MLPClassifier()

# %%
parameter_space = {
    'hidden_layer_sizes': [(300,200,), (300,150,), (300,100,)],
    'activation': ['relu'],
    'solver': [ 'adam'],
    'alpha': [0.001],
    'learning_rate': ['constant'],
    'max_iter' : [5000, 6000, 7000],
    'early_stopping' : [False]
}
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=10)
clf.fit(x_train, y_train) # X is train samples and y is the corresponding labels
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['relu'], 'alpha': [0.001],
#                          'early_stopping': [False],
#                          'hidden_layer_sizes': [(300, 200), (300, 150),
#                                                 (300, 100)],
#                          'learning_rate': ['constant'],
#                          'max_iter': [5000, 6000, 7000], 'solver': ['adam']})

# %%
print('Best parameters found:\n', clf.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 100), 'learning_rate': 'constant', 'max_iter': 7000, 'solver': 'adam'}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.808 (+/-0.027) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 200), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.807 (+/-0.026) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 200), 'learning_rate': 'constant', 'max_iter': 6000, 'solver': 'adam'}
# 0.813 (+/-0.027) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 200), 'learning_rate': 'constant', 'max_iter': 7000, 'solver': 'adam'}
# 0.815 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.805 (+/-0.022) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 150), 'learning_rate': 'constant', 'max_iter': 6000, 'solver': 'adam'}
# 0.809 (+/-0.019) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 150), 'learning_rate': 'constant', 'max_iter': 7000, 'solver': 'adam'}
# 0.814 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 100), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.811 (+/-0.021) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 100), 'learning_rate': 'constant', 'max_iter': 6000, 'solver': 'adam'}
# 0.816 (+/-0.024) for {'activation': 'relu', 'alpha': 0.001, 'early_stopping': False, 'hidden_layer_sizes': (300, 100), 'learning_rate': 'constant', 'max_iter': 7000, 'solver': 'adam'}

# %%
y_true, y_pred = y_test , clf.predict(x_test)
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      4472
#            1       0.67      0.61      0.64      1456
#
#     accuracy                           0.83      5928
#    macro avg       0.77      0.76      0.77      5928
# weighted avg       0.83      0.83      0.83      5928

# %%
precision_recall_fscore_support(y_true, y_pred, average='macro')
# Out:
# (0.7748054344858355, 0.7576827242524917, 0.7654639719298402, None)

# %%
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")

plt.show()

# %%
outputs= clf.predict(first_match15)
cm = confusion_matrix(first_output15, clf.predict(first_match15))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Model 1 complete

# %%
model_1_output = pd.DataFrame()
model_1_output['Input'] = first_match15
model_1_output['Output'] = outputs

# %%
model_1_training_output = pd.DataFrame()
model_1_training_output['Input'] = x_test 
model_1_training_output['Output'] = y_pred

# %%
true_model_output = model_1_output.loc[model_1_output['Output'] == 1]
true_training_model_output = model_1_training_output.loc[model_1_training_output['Output'] == 1]

# %%
true_model_output.shape
# Out:
# (228, 2)

# %%
inputs = true_model_output['Input'].to_numpy()
inputs = inputs.tolist()
input2 =[]
for i in range(len(inputs)):
    input2.append(inputs[i][0:100])
input_no_dup =  [i for n, i in enumerate(input2) if i not in input2[:n]]
input_pairs = create_pairs([df15], input_no_dup)
# Out:
# 175
# [1.102953208, -0.099438375, 1.099476929, 0.843701931, 0.929993694, 1.698734285, 1.107320036, 1.174954371, 1.745608336, 1.604009519, 0.494014101, 0.440343278, 0.85264189, 2.304048468, 1.300061837, 2.043710231, 1.123244983, 0.44548638, 1.035307687, 1.180825893]
# 15925

# %%
training_inputs = true_training_model_output['Input'].to_numpy()
training_inputs = training_inputs.tolist()
train_inputs2 = []
for i in range(len(training_inputs)):
    train_inputs2.append(training_inputs[i][0:100])
train_input_no_dup =  [i for n, i in enumerate(train_inputs2) if i not in train_inputs2[:n]]
print(len(train_input_no_dup))
train_input_pairs = create_pairs([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14], train_input_no_dup)
# Out:
# 5
#       master_chronology    SLC08A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.418635
# 1992           1.510471  1.606258
# 1993           1.399487  2.468107
# 1994          -0.236549  0.752298
# 1995           1.370315  0.483366
#
# [366 rows x 2 columns]
#       master_chronology    SLC07B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.771311
# 1992           1.510471  2.872836
# 1993           1.399487  1.310599
# 1994          -0.236549 -0.825097
# 1995           1.370315  0.679461
#
# [366 rows x 2 columns]
#       master_chronology    SLC07A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.569248
# 1992           1.510471  2.246548
# 1993           1.399487  1.990881
# 1994          -0.236549  0.088342
# 1995           1.370315  1.623497
#
# [366 rows x 2 columns]
#       master_chronology    SLC06B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.996815
# 1992           1.510471  1.409192
# 1993           1.399487  1.799999
# 1994          -0.236549 -0.452017
# 1995           1.370315  1.823759
#
# [366 rows x 2 columns]
#       master_chronology    SLC05B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.895386
# 1992           1.510471  1.690698
# 1993           1.399487  1.615531
# 1994          -0.236549 -0.746369
# 1995           1.370315  1.742115
#
# [366 rows x 2 columns]
#       master_chronology    SLC06A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.546358
# 1992           1.510471  1.213632
# 1993           1.399487  1.927465
# 1994          -0.236549 -0.046801
# 1995           1.370315  1.612224
#
# [366 rows x 2 columns]
#       master_chronology    SLC05A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.696656
# 1992           1.510471  1.319566
# 1993           1.399487  1.743868
# 1994          -0.236549 -0.426104
# 1995           1.370315  1.465922
#
# [366 rows x 2 columns]
#       master_chronology    SLC04B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.324909
# 1992           1.510471  2.072903
# 1993           1.399487  2.154732
# 1994          -0.236549 -0.771648
# 1995           1.370315  1.024795
#
# [366 rows x 2 columns]
#       master_chronology    SLC04A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  0.891876
# 1992           1.510471  1.240107
# 1993           1.399487  1.541581
# 1994          -0.236549 -0.397029
# 1995           1.370315  2.212659
#
# [366 rows x 2 columns]
#       master_chronology  SLC03B
# year
# 1630           2.235870     NaN
# 1631           1.132329     NaN
# 1632          -0.841564     NaN
# 1633          -0.130124     NaN
# 1634           1.247763     NaN
# ...                 ...     ...
# 1991           1.452270     NaN
# 1992           1.510471     NaN
# 1993           1.399487     NaN
# 1994          -0.236549     NaN
# 1995           1.370315     NaN
#
# [366 rows x 2 columns]
#       master_chronology    SLC03A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  2.029666
# 1992           1.510471  0.744454
# 1993           1.399487  0.692761
# 1994          -0.236549 -0.213533
# 1995           1.370315  1.649689
#
# [366 rows x 2 columns]
#       master_chronology    SLC02B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.309737
# 1992           1.510471  1.629997
# 1993           1.399487  1.466743
# 1994          -0.236549 -0.546406
# 1995           1.370315  1.740003
#
# [366 rows x 2 columns]
#       master_chronology    SLC02A
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  2.259642
# 1992           1.510471  1.884882
# 1993           1.399487  0.507323
# 1994          -0.236549 -0.632597
# 1995           1.370315  1.747377
#
# [366 rows x 2 columns]
#       master_chronology    SLC01B
# year
# 1630           2.235870       NaN
# 1631           1.132329       NaN
# 1632          -0.841564       NaN
# 1633          -0.130124       NaN
# 1634           1.247763       NaN
# ...                 ...       ...
# 1991           1.452270  1.603772
# 1992           1.510471  1.168856
# 1993           1.399487  1.243103
# 1994          -0.236549 -0.098164
# 1995           1.370315  1.344243
#
# [366 rows x 2 columns]
# [[2.259505324, 1.61886373, 1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215], [1.61886373, 1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723], [1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035], [1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809], [1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639], [-1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022], [-0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843], [0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434], [0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567], [1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163], [1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973], [0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051], [1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384], [1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193], [1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904], [2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415], [0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618], [1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343], [1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768], [0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898], [0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791], [1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346], [1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776], [0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562], [0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287], [0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279], [0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1.2024902], [-0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1.2024902, -0.096043626], [0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1.2024902, -0.096043626, 1.400711134], [-0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1.2024902, -0.096043626, 1.400711134, 1.405525009], [1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1 ...
# 218
# [2.259505324, 1.61886373, 1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 2.378518557, 1.741895741, -0.266913001, 1.886667439, -0.617144859, 0.162660718, 0.085445783, 0.704041413, 1.665141301, 2.767813643]
# 19838

# %%
binary_training = create_overlap_binary_class(train_input_pairs, correct_pair_training)
binary = create_overlap_binary_test_class(input_pairs, correct_pair15)

# %%
print(total)
print(Counter(binary))
print(Counter(binary_training))
# Out:
# 2470
# Counter({0: 14924, 1: 1001})
# Counter({0: 1083975, 1: 39875})

# %%
x2 = train_input_pairs
y2 = binary_training

# %%
x2 = pd.Series(x2)
y2 = pd.Series(y2)
print(x2)
print(y2)
# Out:
# 0          [1.102953208, -0.099438375, 1.099476929, 0.843...
# 1          [1.102953208, -0.099438375, 1.099476929, 0.843...
# 2          [1.102953208, -0.099438375, 1.099476929, 0.843...
# 3          [1.102953208, -0.099438375, 1.099476929, 0.843...
# 4          [1.102953208, -0.099438375, 1.099476929, 0.843...
#                                  ...
# 1123845    [0.859686319, 2.001081376, 0.989622859, 0.2308...
# 1123846    [0.859686319, 2.001081376, 0.989622859, 0.2308...
# 1123847    [0.859686319, 2.001081376, 0.989622859, 0.2308...
# 1123848    [0.859686319, 2.001081376, 0.989622859, 0.2308...
# 1123849    [0.859686319, 2.001081376, 0.989622859, 0.2308...
# Length: 1123850, dtype: object
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 1123845    0
# 1123846    0
# 1123847    0
# 1123848    0
# 1123849    0
# Length: 1123850, dtype: int64

# %%
df = pd.concat([x2,y2], axis=1)
print(df)
# Out:
#                                                          0  1
# 0        [1.102953208, -0.099438375, 1.099476929, 0.843...  0
# 1        [1.102953208, -0.099438375, 1.099476929, 0.843...  0
# 2        [1.102953208, -0.099438375, 1.099476929, 0.843...  0
# 3        [1.102953208, -0.099438375, 1.099476929, 0.843...  0
# 4        [1.102953208, -0.099438375, 1.099476929, 0.843...  0
# ...                                                    ... ..
# 1123845  [0.859686319, 2.001081376, 0.989622859, 0.2308...  0
# 1123846  [0.859686319, 2.001081376, 0.989622859, 0.2308...  0
# 1123847  [0.859686319, 2.001081376, 0.989622859, 0.2308...  0
# 1123848  [0.859686319, 2.001081376, 0.989622859, 0.2308...  0
# 1123849  [0.859686319, 2.001081376, 0.989622859, 0.2308...  0
#
# [1123850 rows x 2 columns]

# %%
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size=0.5)
print('Training Data: ')
print(len(x2_train))
print('----------------------------------------------')
print('Testing Data: ')
print(len(x2_test))
# Out:
# Training Data:
# 561925
# ----------------------------------------------
# Testing Data:
# 561925

# %%
print('y_train class distribution')
print(y2_train.value_counts(normalize=True))
print('y_test class distribution')
print(y2_test.value_counts(normalize=True))
# Out:
# y_train class distribution
# 0    0.964413
# 1    0.035587
# dtype: float64
# y_test class distribution
# 0    0.964625
# 1    0.035375
# dtype: float64

# %%
training_set = pd.concat([x2_train, y2_train], axis=1)
match = training_set[training_set.iloc[:, 1] == 1]
no_match = training_set[training_set.iloc[:, 1] == 0]

# %%
undersample = resample(no_match, replace = True, n_samples = len(match))
undersample_train = pd.concat([match, undersample])
print(undersample_train)
undersample_train.iloc[:, 1].value_counts(normalize = True)
# Out:
#                                                         0  1
# 428946  [1.27132117, 0.691233919, 1.382665225, 1.73231...  1
# 72045   [1.174794915, 0.125567498, 0.711881934, 1.2713...  1
# 214972  [0.649502574, 2.526745791, 1.069919454, 1.4305...  1
# 405489  [1.178792732, -0.745138868, 1.197805194, 1.109...  1
# 796319  [-0.161663986, 0.838765258, 1.446305229, 1.319...  1
# ...                                                   ... ..
# 180687  [1.141828302, -1.117592305, 1.423155646, -0.01...  0
# 779985  [0.195886902, 0.472841346, 1.428449981, 0.7356...  0
# 944688  [1.203910163, 0.763167973, 0.294965051, 1.7776...  0
# 332008  [-0.033846841, 1.535953817, 1.813185714, 1.724...  0
# 210547  [1.900369556, 1.15216592, 0.649502574, 2.52674...  0
#
# [39994 rows x 2 columns]
# 1    0.5
# 0    0.5
# Name: 1, dtype: float64

# %%
undersample_x_train = np.array(undersample_train.drop(1, axis = 1))
undersample_y_train = undersample_train[1]
#print(undersample_x_train)
print(undersample_y_train)
undersample_x_train_list = []
for i in range(len(undersample_x_train)):
    if len(undersample_x_train[i][0]) == 20:
        undersample_x_train_list.append(undersample_x_train[i][0])
        i+=1
    else:
        #print(undersample_x_train[i])
        print(len(undersample_x_train[i]))
        i+=1
print(len(x_test))
x_test_list =  np.array(x2_test,dtype = list);
x2_test_final = []
for i in range(len(x_test_list)):

    if len(x_test_list[i]) == 20:
        x2_test_final.append(x_test_list[i])
        i+=1
    else:
        #print(undersample_x_train[i])
        #print(len(undersample_x_train[i]))
        i+=1
print(len(undersample_x_train_list))
print(len(undersample_y_train))
print(len(x2_test_final))
# Out:
# 428946    1
# 72045     1
# 214972    1
# 405489    1
# 796319    1
#          ..
# 180687    0
# 779985    0
# 944688    0
# 332008    0
# 210547    0
# Name: 1, Length: 39994, dtype: int64
# 5928
# 39994
# 39994
# 561925

# %%
mlp2 = MLPClassifier()

# %%
parameter_space = {
    'hidden_layer_sizes': [(120,130,) ,(160,150,), (164,160,120,)],
    'activation': ['relu'],
    'solver': [ 'adam'],
    'alpha': [0.0001],
    'learning_rate': ['constant'],
    'max_iter' : [2300, 2600, 5000],
    'early_stopping' : [False]
}
scorers = {
    'precision_score': make_scorer(precision_score),
    'recall_score': make_scorer(recall_score),
    'accuracy_score': make_scorer(accuracy_score)
}
clf = GridSearchCV(mlp2, parameter_space, n_jobs=-1, cv=10, refit='recall_score')
clf.fit(undersample_x_train_list, undersample_y_train) # X is train samples and y is the corresponding labels
# Out:
# GridSearchCV(cv=10, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['relu'], 'alpha': [0.0001],
#                          'early_stopping': [False],
#                          'hidden_layer_sizes': [(120, 130), (160, 150),
#                                                 (164, 160, 120)],
#                          'learning_rate': ['constant'],
#                          'max_iter': [2300, 2600, 5000], 'solver': ['adam']},
#              refit='recall_score')

# %%
print('Best parameters found:\n', clf.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (164, 160, 120), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.763 (+/-0.011) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (120, 130), 'learning_rate': 'constant', 'max_iter': 2300, 'solver': 'adam'}
# 0.758 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (120, 130), 'learning_rate': 'constant', 'max_iter': 2600, 'solver': 'adam'}
# 0.755 (+/-0.013) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (120, 130), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.770 (+/-0.017) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (160, 150), 'learning_rate': 'constant', 'max_iter': 2300, 'solver': 'adam'}
# 0.771 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (160, 150), 'learning_rate': 'constant', 'max_iter': 2600, 'solver': 'adam'}
# 0.772 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (160, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.784 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (164, 160, 120), 'learning_rate': 'constant', 'max_iter': 2300, 'solver': 'adam'}
# 0.778 (+/-0.020) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (164, 160, 120), 'learning_rate': 'constant', 'max_iter': 2600, 'solver': 'adam'}
# 0.785 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (164, 160, 120), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}

# %%
y2_true, y2_pred = y2_test , clf.predict(x2_test_final)
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y_true, y_pred))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      4472
#            1       0.67      0.61      0.64      1456
#
#     accuracy                           0.83      5928
#    macro avg       0.77      0.76      0.77      5928
# weighted avg       0.83      0.83      0.83      5928

# %%
precision_recall_fscore_support(y_true, y_pred, average='macro')
# Out:
# (0.7748054344858355, 0.7576827242524917, 0.7654639719298402, None)

# %%
cm = confusion_matrix(y2_true, y2_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")

plt.show()

# %%
outputs= clf.predict(input_pairs)
cm = confusion_matrix(binary, clf.predict(input_pairs))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")
plt.show()

# %%
model_2_training_output = pd.DataFrame()
model_2_training_output['Input'] = x2_test_final
model_2_training_output['Output'] = y2_pred

# %%
model_2_output = pd.DataFrame()
model_2_output['Input'] = input_pairs
model_2_output['Output'] = outputs

# %%
true_model_training_output2 = model_2_training_output.loc[model_2_training_output['Output'] == 1]
true_model_output2 = model_2_output.loc[model_2_output['Output'] == 1]

# %%
training_inputs2 = true_model_training_output2['Input'].to_numpy()
inputs2 = true_model_output2['Input'].to_numpy()

# %%
training_inputs3 = training_inputs2.tolist()
inputs3 = inputs2.tolist()

# %%
training_correct = create_binary_training_class(training_inputs2, correct_pair_training)
correct2 = create_binary_class(inputs2, correct_pair15)

# %%
print(Counter(training_correct))
print(Counter(correct2))
# Out:
# Counter({0: 158331, 1: 1553})
# Counter({0: 5703, 1: 80})

# %%
x3 = pd.Series(training_inputs3)
y3 = pd.Series(training_correct)
print(x)
print(y)
# Out:
# 0         [0.565047162, 1.191331802, -0.58347509, 0.8513...
# 1         [1.102953208, -0.099438375, 1.099476929, 0.843...
# 2         [1.204560256, 1.193276075, 0.988821603, -0.206...
# 3         [0.927398762, 1.075315361, 1.001712895, -0.033...
# 4         [0.071805527, 1.178792732, -0.745138868, 1.197...
#                                 ...
# 159879    [1.460833393, 1.495293004, 0.874398708, 1.6561...
# 159880    [-0.216709361, 0.010727464, 0.881658737, 0.856...
# 159881    [0.638175174, 1.671288978, 1.900369556, 1.1521...
# 159882    [1.426087773, 1.748460419, 1.174794915, 0.1255...
# 159883    [2.386359645, 2.042487808, 0.616589862, 1.0209...
# Length: 159884, dtype: object
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 159879    0
# 159880    0
# 159881    0
# 159882    0
# 159883    0
# Length: 159884, dtype: int64

# %%
x3_train,x3_test,y3_train,y3_test = train_test_split(x3,y3,test_size=0.5)
print('Training Data: ')
print(len(x_train))
print('----------------------------------------------')
print('Testing Data: ')
print(len(x_test))
# Out:
# Training Data:
# 8892
# ----------------------------------------------
# Testing Data:
# 5928

# %%
training_set3 = pd.concat([x3_train, y3_train], axis=1)
match3 = training_set3[training_set3.iloc[:, 1] == 1]
no_match3 = training_set3[training_set3.iloc[:, 1] == 0]

# %%
undersample3 = resample(no_match3, replace = True, n_samples = len(match3))
undersample_train3 = pd.concat([match3, undersample3])
print(undersample_train3)
undersample_train3.iloc[:, 1].value_counts(normalize = True)
# Out:
#                                                         0  1
# 150831  [0.614422359, -1.05368316, 0.983890537, 1.2296...  1
# 50355   [0.691233919, 1.382665225, 1.732319519, 0.8931...  1
# 38151   [1.63330959, 0.576766, 0.072002263, 1.44754340...  1
# 145806  [-0.216709361, 0.010727464, 0.881658737, 0.856...  1
# 56104   [0.843701931, 0.929993694, 1.698734285, 1.1073...  1
# ...                                                   ... ..
# 107110  [0.018610628, 1.72234699, 1.63330959, 0.576766...  0
# 68226   [0.983890537, 1.229624714, 1.919851172, 0.1561...  0
# 45912   [1.10422011, 1.24716579, 0.985109233, -0.21670...  0
# 29794   [0.210743951, 1.962487951, 0.859686319, 2.0010...  0
# 141710  [2.238137371, 1.109096089, 2.16627845, 0.56808...  0
#
# [1534 rows x 2 columns]
# 1    0.5
# 0    0.5
# Name: 1, dtype: float64

# %%
undersample_x_train3 = np.array(undersample_train3.drop(1, axis = 1))
undersample_y_train3 = undersample_train3[1]
#print(undersample_x_train)
print(undersample_y_train3)
undersample_x_train_list3 = []
for i in range(len(undersample_x_train3)):
    if len(undersample_x_train3[i][0]) == 20:
        undersample_x_train_list3.append(undersample_x_train3[i][0])
        i+=1
    else:
        continue
        i+=1
x_test_list3 =  np.array(x3_test,dtype = list)
x_test_final3 = []
for i in range(len(x_test_list3)):
    if len(x_test_list3[i]) == 20:
        x_test_final3.append(x_test_list3[i])
    else:
        #print(undersample_x_train[i])
        #print(len(undersample_x_train[i]))
        continue
print(len(undersample_x_train_list3))
print(len(undersample_y_train3))
print(len(x_test_final3))
# Out:
# 150831    1
# 50355     1
# 38151     1
# 145806    1
# 56104     1
#          ..
# 107110    0
# 68226     0
# 45912     0
# 29794     0
# 141710    0
# Name: 1, Length: 1534, dtype: int64
# 1534
# 1534
# 79942

# %%
mlp3 = MLPClassifier()

# %%
parameter_space = {

    'hidden_layer_sizes': [(300,),(500,), (500,150,), (550,), (500,250,)],
    'activation': ['relu'],
    'solver': [ 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant', 'invscaling', 'adaptive'],
    'max_iter' : [100, 200, 500, 1000, 2000,5000],
    'early_stopping' : [True, False]
}
clf = GridSearchCV(mlp, parameter_space, n_jobs=-1, cv=10)
clf.fit(undersample_x_train_list3, undersample_y_train3) # X is train samples and y is the corresponding labels
# Out:
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/ursulamennear/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# GridSearchCV(cv=10, estimator=MLPClassifier(), n_jobs=-1,
#              param_grid={'activation': ['relu'], 'alpha': [0.0001, 0.05],
#                          'early_stopping': [True, False],
#                          'hidden_layer_sizes': [(300,), (500,), (500, 150),
#                                                 (550,), (500, 250)],
#                          'learning_rate': ['constant', 'invscaling',
#                                            'adaptive'],
#                          'max_iter': [100, 200, 500, 1000, 2000, 5000],
#                          'solver': ['adam']})

# %%
print('Best parameters found:\n', clf.best_params_)
# Out:
# Best parameters found:
#  {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}

# %%
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))
# Out:
# 0.879 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.879 (+/-0.071) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.876 (+/-0.069) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.872 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.857 (+/-0.076) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.886 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.862 (+/-0.059) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.867 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.866 (+/-0.059) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.856 (+/-0.066) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.870 (+/-0.054) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.864 (+/-0.060) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.865 (+/-0.074) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.873 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.877 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.866 (+/-0.064) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.868 (+/-0.065) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.876 (+/-0.073) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.865 (+/-0.066) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.870 (+/-0.062) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.882 (+/-0.036) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.869 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.873 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.883 (+/-0.069) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.875 (+/-0.058) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.869 (+/-0.056) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.865 (+/-0.054) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.873 (+/-0.071) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.864 (+/-0.062) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.877 (+/-0.058) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.875 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.890 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.873 (+/-0.087) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.862 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.875 (+/-0.064) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.870 (+/-0.058) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.883 (+/-0.075) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.892 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.892 (+/-0.053) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.890 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.885 (+/-0.053) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.881 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.882 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.896 (+/-0.037) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.880 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.893 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.879 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.890 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.885 (+/-0.071) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.900 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.037) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.882 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.885 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.887 (+/-0.072) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.876 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.862 (+/-0.065) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.875 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.881 (+/-0.058) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.885 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.883 (+/-0.054) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.877 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.874 (+/-0.060) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.874 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.878 (+/-0.053) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.880 (+/-0.064) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.876 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.873 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.892 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.878 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.876 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.872 (+/-0.060) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.887 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.889 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.892 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.894 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.893 (+/-0.059) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.893 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.891 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.881 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.895 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.880 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.895 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.887 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.885 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.889 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.885 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.889 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.894 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.880 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.887 (+/-0.052) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.903 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.907 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.059) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.902 (+/-0.033) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.906 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.899 (+/-0.033) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.904 (+/-0.036) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.909 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.904 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.896 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.902 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.909 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.907 (+/-0.032) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.907 (+/-0.046) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.905 (+/-0.060) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.899 (+/-0.052) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.901 (+/-0.033) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.898 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.898 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.046) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.897 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.904 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.901 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.910 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.900 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.905 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.903 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.054) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.909 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.046) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.908 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.901 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.903 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.904 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.907 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.896 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.903 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.895 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.898 (+/-0.058) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.896 (+/-0.032) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.906 (+/-0.035) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.894 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.898 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.904 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.904 (+/-0.061) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.902 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.896 (+/-0.034) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.895 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.900 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.905 (+/-0.036) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.904 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.894 (+/-0.038) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.900 (+/-0.029) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.901 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.900 (+/-0.047) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.048) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.902 (+/-0.032) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.901 (+/-0.037) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.904 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.900 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.908 (+/-0.050) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.901 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.908 (+/-0.046) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.900 (+/-0.039) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.902 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.904 (+/-0.043) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.904 (+/-0.055) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.903 (+/-0.056) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.900 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.892 (+/-0.053) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.893 (+/-0.040) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.897 (+/-0.045) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.903 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.905 (+/-0.046) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.901 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.896 (+/-0.042) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.896 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.036) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.902 (+/-0.064) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.903 (+/-0.044) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.894 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.895 (+/-0.057) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.899 (+/-0.051) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.902 (+/-0.049) for {'activation': 'relu', 'alpha': 0.0001, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.858 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.881 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.861 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.862 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.870 (+/-0.070) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.882 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.883 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.871 (+/-0.067) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.864 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.873 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.874 (+/-0.038) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.873 (+/-0.060) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.870 (+/-0.089) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.877 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.866 (+/-0.066) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.869 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.845 (+/-0.069) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.860 (+/-0.066) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.862 (+/-0.087) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.879 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.868 (+/-0.076) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.886 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.881 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.885 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.872 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.872 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.882 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.868 (+/-0.073) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.870 (+/-0.070) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.863 (+/-0.068) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.872 (+/-0.049) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.884 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.874 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.863 (+/-0.086) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.867 (+/-0.065) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.879 (+/-0.064) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.887 (+/-0.033) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.887 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.885 (+/-0.064) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.889 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.894 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.883 (+/-0.038) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.876 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.896 (+/-0.038) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.885 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.890 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.892 (+/-0.029) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.883 (+/-0.063) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.888 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.883 (+/-0.036) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.895 (+/-0.040) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.885 (+/-0.070) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.875 (+/-0.065) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.890 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.885 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.880 (+/-0.068) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.882 (+/-0.031) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.870 (+/-0.059) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.880 (+/-0.049) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.874 (+/-0.040) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.870 (+/-0.065) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.882 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.876 (+/-0.076) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.870 (+/-0.070) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.879 (+/-0.066) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.882 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.872 (+/-0.059) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.875 (+/-0.047) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.879 (+/-0.057) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.875 (+/-0.068) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.876 (+/-0.062) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.883 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.902 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.897 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.032) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.885 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.885 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.880 (+/-0.066) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.891 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.883 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.890 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.894 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.890 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.902 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': True, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# ...
# 0.904 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.904 (+/-0.040) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.905 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.905 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.902 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.904 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.904 (+/-0.047) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.904 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.904 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.047) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.902 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.900 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.897 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (300,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.907 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.906 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.898 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.907 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.903 (+/-0.042) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.899 (+/-0.036) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.902 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.905 (+/-0.049) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.906 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.907 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.900 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.901 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.901 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.903 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.904 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.900 (+/-0.047) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.907 (+/-0.040) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.906 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.901 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.901 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.902 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.898 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.904 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.906 (+/-0.059) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.900 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.904 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.896 (+/-0.053) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.901 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.901 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.900 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.899 (+/-0.040) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.898 (+/-0.034) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.894 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.894 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 150), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.909 (+/-0.035) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.905 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.902 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.055) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.906 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.906 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.903 (+/-0.045) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.905 (+/-0.035) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.904 (+/-0.054) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.900 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.905 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.903 (+/-0.036) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.905 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.905 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.903 (+/-0.052) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.901 (+/-0.046) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.907 (+/-0.062) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (550,), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}
# 0.896 (+/-0.041) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'adam'}
# 0.904 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'adam'}
# 0.903 (+/-0.049) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'adam'}
# 0.899 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 1000, 'solver': 'adam'}
# 0.905 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 2000, 'solver': 'adam'}
# 0.899 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'constant', 'max_iter': 5000, 'solver': 'adam'}
# 0.901 (+/-0.037) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'adam'}
# 0.900 (+/-0.039) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'adam'}
# 0.894 (+/-0.065) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'adam'}
# 0.900 (+/-0.063) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 1000, 'solver': 'adam'}
# 0.905 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 2000, 'solver': 'adam'}
# 0.903 (+/-0.048) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'invscaling', 'max_iter': 5000, 'solver': 'adam'}
# 0.900 (+/-0.043) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'adam'}
# 0.907 (+/-0.050) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'adam'}
# 0.905 (+/-0.044) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'adam'}
# 0.892 (+/-0.059) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 1000, 'solver': 'adam'}
# 0.900 (+/-0.056) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 2000, 'solver': 'adam'}
# 0.906 (+/-0.051) for {'activation': 'relu', 'alpha': 0.05, 'early_stopping': False, 'hidden_layer_sizes': (500, 250), 'learning_rate': 'adaptive', 'max_iter': 5000, 'solver': 'adam'}

# %%
y3_true, y3_pred = y3_test , clf.predict(x_test_final3)
from sklearn.metrics import classification_report
print('Results on the test set:')
print(classification_report(y3_true, y3_pred))
# Out:
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95     79156
#            1       0.09      0.92      0.16       786
#
#     accuracy                           0.90     79942
#    macro avg       0.54      0.91      0.55     79942
# weighted avg       0.99      0.90      0.94     79942

# %%
cm = confusion_matrix(y3_true, y3_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")

plt.show()

# %%
output3 = clf.predict(inputs3)
cm = confusion_matrix(correct2, output3)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=[0,1], )
disp.plot(cmap="YlGnBu")

plt.show()

# %%
model_3_output = pd.DataFrame()
model_3_output['Input'] = inputs3
model_3_output['Output'] = output3
model_3_output.head()
# Out:
#                                                Input  Output
# 0  [1.102953208, -0.099438375, 1.099476929, 0.843...       0
# 1  [1.102953208, -0.099438375, 1.099476929, 0.843...       0
# 2  [1.102953208, -0.099438375, 1.099476929, 0.843...       0
# 3  [1.102953208, -0.099438375, 1.099476929, 0.843...       0
# 4  [1.102953208, -0.099438375, 1.099476929, 0.843...       0

# %%
true_model3_output = model_3_output.loc[model_3_output['Output'] == 1]
true_model3_output.head()
# Out:
#                                                 Input  Output
# 28  [1.102953208, -0.099438375, 1.099476929, 0.843...       1
# 36  [1.102953208, -0.099438375, 1.099476929, 0.843...       1
# 37  [1.102953208, -0.099438375, 1.099476929, 0.843...       1
# 39  [1.102953208, -0.099438375, 1.099476929, 0.843...       1
# 48  [1.102953208, -0.099438375, 1.099476929, 0.843...       1

# %%
all_contender = true_model3_output['Input'].to_numpy()
print(len(all_contender))
# Out:
# 624

# %%
samples15 = []
i= 0
for col in df15.columns:
    col_list = df15[col].tolist()
    cleanedList = [x for x in col_list if x == x]
    samples15.append(cleanedList)
print(samples15)
print(len(samples15))
print(len(samples15[1]))
# Out:
# [[2.235869998, 1.132328703, -0.841564282, -0.130123647, 1.247762822, 1.638606085, 0.222738524, 1.203137934, 2.055554049, 1.195772282, 1.715856875, 1.386419714, 1.509306738, -0.36778324, -0.453077169, 0.771905572, 1.413592355, 0.820585831, 0.180248886, 0.715319634, 1.978084087, 0.935713879, 0.445541163, 0.877161519, 1.361232496, 2.339152265, 0.566461604, 1.53362851, 0.540780673, 0.308551136, 2.044395312, 1.47138373, 1.475049439, 1.691701112, 0.900841121, 1.267905212, -0.014071594, 0.910193182, -0.400849161, -1.45354612, -0.294211864, -0.266837394, -0.088826567, 2.092952082, 3.398928031, 1.912562577, 0.278125187, 1.6785953, 0.074105503, 1.254530137, 2.259505324, 1.61886373, 1.334944069, 1.124796033, 1.078302631, -1.15032024, -0.055803224, 0.009875286, 0.298643013, 1.157698215, 1.808604723, 0.801203035, 1.338288809, 1.158238639, 1.151479022, 2.438930843, 0.05858434, 1.263130567, 1.203910163, 0.763167973, 0.294965051, 1.777691384, 1.613658193, 0.954481904, 0.38777415, 0.21942618, 0.132244343, -0.09586768, 0.653726898, -0.165818791, 1.611041346, 0.566131776, 1.63327562, 1.348473287, 2.156058279, 1.2024902, -0.096043626, 1.400711134, 1.405525009, 0.609962312, 0.786182286, 0.619887453, 1.064835717, 1.472847164, 0.600358256, 0.67207761, 3.254889453, 1.270796095, 0.698946446, 0.225014364, 0.223577892, 0.606523574, 1.356528075, -0.640031705, 0.606363107, 0.605692487, 1.832131216, 2.219146987, 1.759157167, 0.779751845, 0.34098393, 0.789497318, 0.298639244, 1.513617755, 0.738844866, 1.545611202, 2.514765719, 2.823888628, -0.31842376, 2.313937307, 1.159917323, -0.030625698, -0.354144564, -0.782186774, 0.466602227, 0.483097451, 0.680517949, 0.018610628, 1.72234699, 1.63330959, 0.576766, 0.072002263, 1.447543403, 0.570309357, 2.238137371, 1.109096089, 2.16627845, 0.568081361, 0.210743951, 1.962487951, 0.859686319, 2.001081376, 0.989622859, 0.230879117, 0.658698035, 1.365608245, 0.423844551, 0.648968483, 0.610586414, 0.927398762, 1.075315361, 1.001712895, -0.033389287, 1.535303391, 2.161389732, 2.092127238, 0.805848982, 0.70809498, 0.336572421, 0.614422359, -1.05368316, 0.983890537, 1.229624714, 1.919851172, 0.156136971, 1.414797929, 1.204461843, 0.758141716, 0.790177977, 1.460833393, 1.495293004, 0.874398708, 1.656171241, 0.84156233, 1.017754412, 0.450106447, -0.675201092, 0.982238607, -0.235358335, 1.196279169, 1.963055849, 1.315504628, 1.246151936, 0.65783318, 0.1645754, 2.168636481, 3.144725113, 1.538905648, 0.978225122, 0.025818324, -0.071845175, 1.187562931, 0.195886902, 0.472841346, 1.428449981, 0.735608235, 0.152876503, 0.886677393, 1.139936274, -0.161663986, 0.838765258, 1.446305229, 1.31903956, 1.925385456, 0.508240546, 1.614712987, 0.390438768, 1.841313033, 1.247273017, 2.41206497, 0.974638219, -0.192005708, 0.032174431, -0.119219203, 1.009831407, 1.267842284, 1.747415045, -0.669596561, 0.427490664, 0.877932928, 1.507609542, 0.666174708, 1.67404981, 1.190104003, 0.994235831, 0.864493379, 0.91106358, 0.594996779, 1.290870184, 1.250922635, 1.10422011, 1.24716579, 0.985109233, -0.216709361, 0.010727464, 0.881658737, 0.856546737, 1.261497852, 2.555515487, 1.204560256, 1.193276075, 0.988821603, -0.20639979, -0.033846841, 1.535953817, 1.813185714, 1.724838218, 1.906645971, 0.1928154, 0.326006197, 1.102953208, -0.099438375, 1.099476929, 0.843701931, 0.929993694, 1.698734285, 1.107320036, 1.174954371, 1.745608336, 1.604009519, 1.228487115, 1.7757291, 0.362353034, -0.734506802, 0.216693512, -0.197451161, 0.904732988, 1.123053964, 2.386359645, 2.042487808, 0.616589862, 1.020978421, 0.071805527, 1.178792732, -0.745138868, 1.197805194, 1.10940362, 1.426087773, 1.748460419, 1.174794915, 0.125567498, 0.711881934, 1.27132117, 0.691233919, 1.382665225, 1.732319519, 0.893143726, 1.049950403, 0.224476759, 0.893478456, 1.378306981, 0.900440884, 1.408590281, 0.565047162, 1.191331802, -0.58347509, 0.851354918, 0.717811486, 0.967880783, 1.135879111, 1.559856895, 1.131062812, 1.994332073, 1.101050595, 0.379215038, 1.705598117, 1.607912239, 1.058099801, 0 ...
# 2
# 184

# %%
start_year = []
for i in range (len(all_contender.tolist())):
    (master_seg15, sample_seg15) = all_contender[i][0:9], all_contender[i][10:20]
    #print(f'{i} : {master_seg8, sample_seg8}')
    start_year.append(df15.first_valid_index() + samples15[0].index(master_seg15[0]) - samples15[1].index(sample_seg15[0]))
print(len(start_year))
print(Counter(start_year).most_common(5))
Counter(start_year)[1812]
# Out:
# 624
# [(1812, 76), (1813, 14), (1835, 14), (1874, 13), (1789, 12)]
# 76

# %%
df15.apply(pd.Series.first_valid_index)
# Out:
# master_chronology    1630
# SLC01A               1812
# dtype: int64

# %%
1812-1630
# Out:
# 182

# %%
df15.first_valid_index()
# Out:
# 1630
